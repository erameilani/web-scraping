# %%
#import library yang dibutuhkan
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
#buatlah request ke website
web_url = requests.get('https://id.wikipedia.org/wiki/Demografi_Indonesia').text
soup = BeautifulSoup(web_url,'lxml')

# %%
#ambil table dengan class 'wikitable sortable'
table = soup.find('table', {'class':'wikitable sortable'})

# %%
#cari data dengan tag 'td'
links = table.findAll('td')

# %%
#buatlah lists kosong 
kode_bps = []
nama = []
ibu_kota = []
populasi = []
luas_km = []
pulau = []

# %%
#memasukkan data ke dalam list berdasarkan pola HTML
for i, link in enumerate(links):
    if i in range(0, len(links), 9):
        kode_bps.append(link.get_text())
    if i in range(2, len(links), 9):
        nama.append(link.get_text())
    if i in range(4, len(links), 9):
        ibu_kota.append(link.get_text())
    if i in range(5, len(links), 9):
        populasi.append(link.get_text())
    if i in range(6, len(links), 9):
        luas_km.append(link.get_text())
    if i in range(8, len(links), 9):
        pulau.append(link.get_text()[:-1])

# %%
#buatlah DataFrame dan masukkan ke CSV
df = pd.DataFrame()
df['Kode BPS'] = kode_bps
df['Nama'] = nama
df['Ibu Kota'] = ibu_kota
df['Populasi'] = populasi
df['Luas km'] = luas_km
df['Pulau'] = pulau
df.to_csv('Indonesia_Demography_by_Province.csv', index=False, encoding='utf-8', quoting=1)

# %%
df
# Out:
#    Kode BPS                           Nama        Ibu Kota    Populasi  \
# 0        11                           Aceh      Banda Aceh   4.494.410
# 1        12                  Sumatra Utara           Medan  12.982.204
# 2        13                  Sumatra Barat          Padang   4.846.909
# 3        14                           Riau       Pekanbaru   5.538.367
# 4        15                          Jambi           Jambi   3.092.265
# 5        16                Sumatra Selatan       Palembang   7.450.394
# 6        17                       Bengkulu        Bengkulu   1.715.518
# 7        18                        Lampung  Bandar Lampung   7.608.405
# 8        19      Kepulauan Bangka Belitung  Pangkal Pinang   1.223.296
# 9        21                 Kepulauan Riau  Tanjung Pinang   1.679.163
# 10       31  Daerah Khusus Ibukota Jakarta   Jakarta Pusat   9.607.787
# 11       32                     Jawa Barat         Bandung  43.053.732
# 12       33                    Jawa Tengah        Semarang  32.382.657
# 13       34     Daerah Istimewa Yogyakarta      Yogyakarta   3.457.491
# 14       35                     Jawa Timur        Surabaya  37.476.757
# 15       36                         Banten          Serang  10.632.166
# 16       51                           Bali        Denpasar   3.890.757
# 17       52            Nusa Tenggara Barat         Mataram   4.500.212
# 18       53            Nusa Tenggara Timur          Kupang   4.683.827
# 19       61               Kalimantan Barat       Pontianak   4.395.983
# 20       62              Kalimantan Tengah    Palangkaraya   2.212.089
# 21       63             Kalimantan Selatan     Banjarmasin   3.626.616
# 22       64               Kalimantan Timur       Samarinda   3.553.143
# 23       65               Kalimantan Utara   Tanjung Selor     738.163
# 24       71                 Sulawesi Utara          Manado   2.270.596
# 25       72                Sulawesi Tengah            Palu   2.635.009
# 26       73               Sulawesi Selatan        Makassar   8.034.776
# 27       74              Sulawesi Tenggara         Kendari   2.232.586
# 28       75                      Gorontalo       Gorontalo   1.040.164
# 29       76                 Sulawesi Barat          Mamuju   1.158.651
# 30       81                         Maluku           Ambon   1.533.506
# 31       82                   Maluku Utara          Sofifi   1.038.087
# 32       91                    Papua Barat       Manokwari     760.422
# 33       94                          Papua        Jayapura   2.833.381
#
#        Luas km          Pulau
# 0    56.500,51        Sumatra
# 1    72.427,81        Sumatra
# 2    42.224,65        Sumatra
# 3    87.844,23        Sumatra
# 4    45.348,49        Sumatra
# 5    60.302,54        Sumatra
# 6    19.795,15        Sumatra
# 7    37.735,15        Sumatra
# 8    16.424,14        Sumatra
# 9     8.084,01        Sumatra
# 10      740,29           Jawa
# 11   36.925,05           Jawa
# 12   32.799,71           Jawa
# 13    3.133,15           Jawa
# 14   46.689,64           Jawa
# 15    9.018,64           Jawa
# 16    5.449,37  Nusa Tenggara
# 17   19.708,79  Nusa Tenggara
# 18   46.137,87  Nusa Tenggara
# 19  120.114,32     Kalimantan
# 20  153.564,50     Kalimantan
# 21   37.530,52     Kalimantan
# 22  194.849,08     Kalimantan
# 23   72.567,49     Kalimantan
# 24   13.930,73       Sulawesi
# 25   68.089,83       Sulawesi
# 26   46.116,45       Sulawesi
# 27   36.757,45       Sulawesi
# 28   12.165,44       Sulawesi
# 29   16.787,19       Sulawesi
# 30   47.350,42         Maluku
# 31   39.959,99         Maluku
# 32  114.566,40          Papua
# 33  309.934,40          Papua
